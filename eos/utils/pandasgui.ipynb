# %%
# !which python
# Out:
# /home/is/.pyenv/versions/3.10.4/envs/eos/bin/python

# %%
from pandasgui import show
from eos.utils.plot import plot_3d_figure

show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pm_path = "../../data/"
pd_data0 = pd.read_csv(pm_path + "vb7_init_table.csv", header=0, index_col=0)

# %%
df = pd_data0.unstack().reset_index()
df.columns = ["pedal", "velocity", "torque"]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
surf = ax.plot_trisurf(
    df["pedal"],
    df["velocity"],
    df["torque"],
    cmap=plt.cm.YlGnBu,
    linewidth=5,
)
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.view_init(30, 175)

# %%
X, Y = np.meshgrid(pd_data0.columns, pd_data0.index)

# %%
ax1 = fig.add_subplot(projection="3d")
surf1 = ax1.plot_surface(
    X,
    Y,
    np.array(pd_data0.values),
)
fig.colorbar(surf1, shrink=0.5, aspect=5)
ax.view_init(30, 135)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 2>()
#       1 ax1 = fig.add_subplot(projection="3d")
# ----> 2 surf1 = ax1.plot_surface(
#       3     X,
#       4     Y,
#       5     np.array(pd_data0.values),
#       6 )
#       7 fig.colorbar(surf1, shrink=0.5, aspect=5)
#       8 ax.view_init(30, 135)
#
# File ~/.pyenv/versions/3.10.4/envs/eos/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~/.pyenv/versions/3.10.4/envs/eos/lib/python3.10/site-packages/mpl_toolkits/mplot3d/axes3d.py:1662, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1657                 colset.append(fcolors[rs][cs])
#    1659 # In cases where there are NaNs in the data (possibly from masked
#    1660 # arrays), artifacts can be introduced. Here check whether NaNs exist
#    1661 # and remove the entries if so
# -> 1662 if not isinstance(polys, np.ndarray) or np.isnan(polys).any():
#    1663     new_polys = []
#    1664     new_colset = []
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
